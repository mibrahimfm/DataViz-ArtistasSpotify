# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Useful functions to be used throughout the code

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
def read_csv(file_name):
    df = pd.read_csv(f"Artista_data/{file_name}.csv", index_col=0)
    #df['release_date'] = df['release_date'].apply(lambda f: datetime.strptime(f, '%Y-%m-%d'))
    return df

# %%
def get_correlation_matrix_by_album(df):
    df = df.sort_values(by='release_date', ascending=True)
    albums = df['album'].unique()    
    dfs = []
    for album in albums:
        dfs.append(df[df['album'] == album])

    #albums = [re.sub("[\(\[].*?[\)\]]", "", a) for a in albums]    
    return combine_correlation_matrices(dfs, albums)

# %%
def combine_correlation_matrices(dfs, columns):
    corrs = None
    for df in dfs:
        corr_df = get_correlation_matrix(df)
        if corrs is None:
            corrs = corr_df
        else:
            corrs = pd.concat([corrs, corr_df], axis=1)
    corrs.columns = columns
    return corrs

# %%
def get_correlation_matrix(df):
    #filter df to only use qunatitative columns
    df = df[['track_number', 'acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'popularity',
       'duration_ms']]
    corr_df = df.corr()[['popularity']]
    corr_df.index = ['Track number', 'Acousticness', 'Danceability', 'Energy', 'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Tempo', 'Valence', 'Popularity', 'Duration (ms)']
    return corr_df[~corr_df.index.isin(['Popularity'])]

# %%
def print_correlation_heatmap(df):
    sns.heatmap(df, vmin=-1, vmax=1, cmap='coolwarm')

# %%
taylor_swift_df = read_csv('taylor_swift_spotify')
ed_sheeran_df = read_csv('ed_sheeran_spotify')
beatles_df = read_csv('beatles_spotify')
elton_john_df = read_csv('elton_john_spotify')
metallica_df = read_csv('metallica_spotify')
rolling_stones_df = read_csv('rolling_stones_spotify')
tame_impala_df = read_csv('tame_impala_spotify')

# %%
combined_df = pd.concat([taylor_swift_df, ed_sheeran_df, beatles_df, elton_john_df, metallica_df, rolling_stones_df, tame_impala_df])
combined_df = combined_df.reset_index()
combined_df.drop('index', axis=1, inplace=True)

# %%
print_correlation_heatmap(get_correlation_matrix(combined_df))

# %%
artists = ["Beatles", "Rolling Stones", "Elton John", "Metallica", "Taylor Swift", "Tame Impala", "Ed Sheeran"]

# %%
correlations_df = combine_correlation_matrices([beatles_df, rolling_stones_df, elton_john_df, metallica_df, taylor_swift_df, tame_impala_df, ed_sheeran_df], artists)
print_correlation_heatmap(correlations_df)

# %%
beatles_albums = get_correlation_matrix_by_album(beatles_df)
print_correlation_heatmap(beatles_albums)

# %%
rolling_stones_albums = get_correlation_matrix_by_album(rolling_stones_df)
print_correlation_heatmap(rolling_stones_albums)

# %%
elton_john_albums = get_correlation_matrix_by_album(elton_john_df)
print_correlation_heatmap(elton_john_albums)

# %%
metallica_albums = get_correlation_matrix_by_album(metallica_df)
print_correlation_heatmap(metallica_albums)
# Out:
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12521 (\N{KATAKANA LETTER RA}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12532 (\N{KATAKANA LETTER VU}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12486 (\N{KATAKANA LETTER TE}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12469 (\N{KATAKANA LETTER SA}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12522 (\N{KATAKANA LETTER RI}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12518 (\N{KATAKANA LETTER YU}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12491 (\N{KATAKANA LETTER NI}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12458 (\N{KATAKANA LETTER O}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12450 (\N{KATAKANA LETTER A}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12490 (\N{KATAKANA LETTER NA}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 12480 (\N{KATAKANA LETTER DA}) missing from current font.
#   fig.canvas.draw()
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12521 (\N{KATAKANA LETTER RA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12532 (\N{KATAKANA LETTER VU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12486 (\N{KATAKANA LETTER TE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12469 (\N{KATAKANA LETTER SA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12522 (\N{KATAKANA LETTER RI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12518 (\N{KATAKANA LETTER YU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12491 (\N{KATAKANA LETTER NI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12458 (\N{KATAKANA LETTER O}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12450 (\N{KATAKANA LETTER A}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12490 (\N{KATAKANA LETTER NA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 12480 (\N{KATAKANA LETTER DA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12521 (\N{KATAKANA LETTER RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12452 (\N{KATAKANA LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12532 (\N{KATAKANA LETTER VU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12531 (\N{KATAKANA LETTER N}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12486 (\N{KATAKANA LETTER TE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12469 (\N{KATAKANA LETTER SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12522 (\N{KATAKANA LETTER RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12518 (\N{KATAKANA LETTER YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12491 (\N{KATAKANA LETTER NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12458 (\N{KATAKANA LETTER O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12450 (\N{KATAKANA LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12490 (\N{KATAKANA LETTER NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 12480 (\N{KATAKANA LETTER DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
taylor_swift_albums = get_correlation_matrix_by_album(taylor_swift_df)
print_correlation_heatmap(taylor_swift_albums)

# %%
tame_impala_albums = get_correlation_matrix_by_album(tame_impala_df)
print_correlation_heatmap(tame_impala_albums)

# %%
ed_sheeran_albums = get_correlation_matrix_by_album(ed_sheeran_df)
print_correlation_heatmap(ed_sheeran_albums)
